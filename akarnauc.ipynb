# %% [markdown]
# A Survey on Technology Choice
# ======
# ## Hypothesis
# My response variable is **Issue backlog** (PG5_2BNUI). I think the priority of this variable is going to be affected by the survey question: *In how many many software projects have you been involved?* (PG9Resp). The reasoning behind this is that developers who have been on more projects have probably used a larger variety of packages. As a result, they are likely to have more insight into which packages they prefer vs. packages they have used in the past that were not as successful for their project(s). Thus, I think survey takers who have been involved more projects will place **Issue backlog** as a higher priority than others. Also, PG8Resp (Type of developer) might also play a role because Software Developers might have a lot more exposure to VCS systems like GitHub while Data Scientists might not have to interact with them as much.

# %%
# For nicer printing
options(digits=2);

# %% [markdown]
# ## Data Extraction
# We begin by extracting all of the raw data and converting and calculating time differences between survey questions. We then look at our dataset.

# %%
# Read in the data
data <- read.csv("TechSurvey - Survey.csv",header=T);

#convert date to unix second
for (i in c("Start", "End")) 
    data[,i] = as.numeric(as.POSIXct(strptime(data[,i], "%Y-%m-%d %H:%M:%S")))
for (i in 0:12){
    vnam = paste(c("PG",i,"Submit"), collapse="")
    data[,vnam] = as.numeric(as.POSIXct(strptime(data[,vnam], "%Y-%m-%d %H:%M:%S")))
}
#calculate differences in time    
for (i in 12:0){
    pv = paste(c("PG",i-1,"Submit"), collapse="");
    if (i==0) 
        pv="Start";
    vnam = paste(c("PG",i,"Submit"), collapse="");
    data[,vnam] = data[,vnam] -data[,pv];
}
#now explore variables
summary(data);
# Out:
#      Device    Completed       Start               End               PG0Dis
#         :  2   0    :  2   Min.   :1.54e+09   Min.   :1.54e+09   Min.   :  0
#  Bot    :  1   FALSE:546   1st Qu.:1.54e+09   1st Qu.:1.54e+09   1st Qu.:  0
#  PC     :955   TRUE :805   Median :1.54e+09   Median :1.54e+09   Median :  1
#  Phone  :376               Mean   :1.54e+09   Mean   :1.54e+09   Mean   : 44
#  Tablet : 16               3rd Qu.:1.54e+09   3rd Qu.:1.54e+09   3rd Qu.: 24
#  Unknown:  3               Max.   :1.54e+09   Max.   :1.54e+09   Max.   :168
#                            NA's   :2          NA's   :548        NA's   :73
#     PG0Shown      PG0Submit                                     PG1PsnUse
#  Min.   :   0   Min.   :    2   For personal work and/or research use:727
#  1st Qu.:   0   1st Qu.:    6                                        :613
#  Median : 102   Median :    9   Chapter book                         :  1
#  Mean   : 249   Mean   :  299   dissertation research                :  1
#  3rd Qu.: 428   3rd Qu.:   15   for teaching                         :  1
#  Max.   :1190   Max.   :76226   for teaching undergraduate statistics:  1
#  NA's   :73     NA's   :199     (Other)                              :  9
#                                                                         PG1WdAuth
#                                                                              :1145
#  Because Microsoft was paying me to do it                                    :   1
#  For a wider audience, such as developers of other packages or other software: 205
#  Hackathon                                                                   :   1
#  Tool for other researchers to analyse their data                            :   1
#
#
#                                 PG1Trn
#                                    :1168
#  For a training / class that I took: 184
#  teaching economics                :   1
#
#
#
#
#                                                                PG1Other
#                                                                    :1272
#  Other                                                             :  23
#  teaching                                                          :   3
#  Teaching                                                          :   3
#  For training that I gave                                          :   2
#  How does software technology spreads in the open source community?:   2
#  (Other)                                                           :  48
#    PG1Submit        PG2Resp      PG2Submit
#  Min.   :   1           :431   Min.   :   1
#  1st Qu.:  11   No      :374   1st Qu.:   9
#  Median :  16   Not sure:303   Median :  13
#  Mean   :  39   Yes     :245   Mean   :  29
#  3rd Qu.:  30                  3rd Qu.:  29
#  Max.   :6892                  Max.   :1470
#  NA's   :282                   NA's   :377
#                                                                             PG2Resp.1
#                                                                                  :480
#  The core "data.frame" object lacked functionality that I needed                 :354
#  I saw a recommendation for the package                                          :149
#  Chose the package to be compatible with other packages in my project            :137
#  I didn't choose to use the package, it was included implicitly / unintentionally: 39
#  Other                                                                           :  6
#  (Other)                                                                         :188
#    PG3Submit      PG4Dtr0_6      PG4Psv7_8      PG4Prm9_10    PG4AllResp
#  Min.   :   1   Min.   :0      Min.   :7      Min.   : 9    Min.   : 0
#  1st Qu.:  16   1st Qu.:3      1st Qu.:7      1st Qu.:10    1st Qu.: 8
#  Median :  23   Median :5      Median :8      Median :10    Median : 9
#  Mean   :  44   Mean   :4      Mean   :8      Mean   :10    Mean   : 8
#  3rd Qu.:  40   3rd Qu.:6      3rd Qu.:8      3rd Qu.:10    3rd Qu.:10
#  Max.   :4648   Max.   :6      Max.   :8      Max.   :10    Max.   :10
#  NA's   :451    NA's   :1232   NA's   :1115   NA's   :869   NA's   :510
#    PG4Submit             PG5_1RRPQ     PG5_1Order                PG5_1Time
#  Min.   :  1                  :877   Min.   : 1                       :877
#  1st Qu.:  6   Essential      : 60   1st Qu.: 4    2018-10-11 13:32:57:  3
#  Median :  7   High Priority  :102   Median : 7    2018-10-11 13:29:20:  2
#  Mean   :  9   Low Priority   : 85   Mean   : 7    2018-10-11 13:34:56:  2
#  3rd Qu.:  9   Medium Priority:134   3rd Qu.:11    2018-10-11 13:14:25:  1
#  Max.   :332   Not a Priority : 95   Max.   :20    2018-10-11 13:14:45:  1
#  NA's   :473                         NA's   :877   (Other)            :467
#            PG5_2BNUI     PG5_2Order                PG5_2Time
#                 :923   Min.   : 1                       :923
#  Essential      :  3   1st Qu.: 5    2018-10-11 13:21:46:  2
#  High Priority  : 26   Median : 8    2018-10-11 13:38:07:  2
#  Low Priority   :121   Mean   : 8    2018-10-11 13:14:27:  1
#  Medium Priority: 92   3rd Qu.:11    2018-10-11 13:14:40:  1
#  Not a Priority :188   Max.   :21    2018-10-11 13:15:18:  1
#                        NA's   :923   (Other)            :423
#             PG5_3HDS     PG5_3Order                PG5_3Time
#                 :768   Min.   : 1                       :768
#  Essential      :103   1st Qu.: 2    2018-10-11 13:54:00:  2
#  High Priority  :200   Median : 4    2018-10-11 14:21:45:  2
#  Low Priority   : 69   Mean   : 6    2018-10-11 14:25:51:  2
#  Medium Priority:162   3rd Qu.: 9    2018-10-11 17:21:39:  2
#  Not a Priority : 51   Max.   :19    2018-10-11 13:14:18:  1
#                        NA's   :768   (Other)            :576
#             PG5_4VGP     PG5_4Order                PG5_4Time
#                 :852   Min.   : 1                       :852
#  Essential      : 22   1st Qu.: 4    2018-10-11 13:16:50:  2
#  High Priority  :111   Median : 6    2018-10-11 13:29:51:  2
#  Low Priority   : 88   Mean   : 7    2018-10-11 13:37:39:  2
#  Medium Priority:164   3rd Qu.:10    2018-10-11 13:38:11:  2
#  Not a Priority :116   Max.   :18    2018-10-11 15:42:22:  2
#                        NA's   :852   (Other)            :491
#             PG5_5PHR     PG5_5Order                PG5_5Time
#                 :753   Min.   : 1                       :753
#  Essential      : 79   1st Qu.: 2    2018-10-11 13:18:47:  2
#  High Priority  :252   Median : 4    2018-10-11 13:18:48:  2
#  Low Priority   : 63   Mean   : 6    2018-10-11 13:32:40:  2
#  Medium Priority:162   3rd Qu.: 8    2018-10-11 13:38:12:  2
#  Not a Priority : 44   Max.   :18    2018-10-11 13:45:48:  2
#                        NA's   :753   (Other)            :590
#            PG5_6SSYOP    PG5_6Order                PG5_6Time
#                 :852   Min.   : 1                       :852
#  Essential      : 63   1st Qu.: 3    2018-10-11 13:20:00:  2
#  High Priority  :137   Median : 6    2018-10-11 13:40:53:  2
#  Low Priority   : 84   Mean   : 7    2018-10-11 13:44:00:  2
#  Medium Priority:110   3rd Qu.:10    2018-10-11 13:45:41:  2
#  Not a Priority :107   Max.   :17    2018-10-11 16:22:38:  2
#                        NA's   :852   (Other)            :491
#            PG5_7NDYP     PG5_7Order                PG5_7Time
#                 :934   Min.   : 1                       :934
#  Essential      :  8   1st Qu.: 4    2018-10-11 13:18:50:  2
#  High Priority  : 31   Median : 7    2018-10-11 14:23:19:  2
#  Low Priority   : 93   Mean   : 7    2018-10-11 13:14:22:  1
#  Medium Priority: 52   3rd Qu.:11    2018-10-11 13:14:50:  1
#  Not a Priority :235   Max.   :17    2018-10-11 13:15:08:  1
#                        NA's   :934   (Other)            :412
#             PG5_8CP      PG5_8Order                PG5_8Time
#                 :715   Min.   : 1                       :715
#  Essential      :232   1st Qu.: 1    2018-10-11 13:29:46:  2
#  High Priority  :197   Median : 4    2018-10-11 13:37:00:  2
#  Low Priority   : 52   Mean   : 5    2018-10-11 13:38:36:  2
#  Medium Priority:121   3rd Qu.: 8    2018-10-11 13:39:22:  2
#  Not a Priority : 36   Max.   :20    2018-10-11 14:02:46:  2
#                        NA's   :715   (Other)            :628
#             PG5_9FRP     PG5_9Order                PG5_9Time
#                 :738   Min.   : 1                       :738
#  Essential      :165   1st Qu.: 2    2018-10-11 13:35:13:  2
#  High Priority  :243   Median : 4    2018-10-11 13:37:34:  2
#  Low Priority   : 42   Mean   : 5    2018-10-11 14:02:44:  2
#  Medium Priority:125   3rd Qu.: 9    2018-10-11 13:14:17:  1
#  Not a Priority : 40   Max.   :19    2018-10-11 13:14:52:  1
#                        NA's   :738   (Other)            :607
#            PG5_10RPA    PG5_10Order                PG5_10Time
#                 :779   Min.   : 1                       :779
#  Essential      : 55   1st Qu.: 2    2018-10-11 13:17:47:  2
#  High Priority  :204   Median : 5    2018-10-11 13:27:48:  2
#  Low Priority   : 79   Mean   : 6    2018-10-11 13:45:33:  2
#  Medium Priority:151   3rd Qu.: 9    2018-10-11 15:30:40:  2
#  Not a Priority : 85   Max.   :22    2018-10-11 15:48:40:  2
#                        NA's   :779   (Other)            :564
#            PG5_11NSG    PG5_11Order                PG5_11Time
#                 :890   Min.   : 1                       :890
#  Essential      :  6   1st Qu.: 4    2018-10-11 13:19:44:  2
#  High Priority  : 29   Median : 6    2018-10-11 13:21:53:  2
#  Low Priority   : 89   Mean   : 7    2018-10-11 13:31:08:  2
#  Medium Priority: 68   3rd Qu.:10    2018-10-11 13:40:48:  2
#  Not a Priority :271   Max.   :18    2018-10-11 14:55:47:  2
#                        NA's   :890   (Other)            :453
#            PG5_12NWG    PG5_12Order                PG5_12Time
#                 :916   Min.   : 1                       :916
#  High Priority  : 10   1st Qu.: 5    2018-10-11 13:30:08:  2
#  Low Priority   : 77   Median : 7    2018-10-11 13:31:20:  2
#  Medium Priority: 25   Mean   : 7    2018-10-11 14:55:40:  2
#  Not a Priority :325   3rd Qu.:11    2018-10-11 13:14:46:  1
#                        Max.   :18    2018-10-11 13:14:50:  1
#                        NA's   :916   (Other)            :429
#            PG5_13NFG    PG5_13Order                PG5_13Time    PG5Submit
#                 :920   Min.   : 1                       :920   Min.   :   3
#  High Priority  : 10   1st Qu.: 4    2018-10-11 13:17:39:  2   1st Qu.:  45
#  Low Priority   : 76   Median : 7    2018-10-11 13:35:20:  2   Median :  62
#  Medium Priority: 37   Mean   : 7    2018-10-11 13:35:56:  2   Mean   :  87
#  Not a Priority :310   3rd Qu.:10    2018-10-11 15:42:36:  2   3rd Qu.:  84
#                        Max.   :17    2018-10-11 13:14:41:  1   Max.   :4130
#                        NA's   :920   (Other)            :424   NA's   :544
#               PG6Resp      PG6Submit         PG7R      PG7C.C..     PG7Java
#                   :549   Min.   :   1   R      :684        :1268        :1306
#  13 - 19 years    : 50   1st Qu.:   7          :614   C/C++:  84   Java :  46
#  2 - 5 years      :332   Median :   9   Perl   :  6   Cobol:   1   scala:   1
#  20 years or more : 45   Mean   :  24   PHP    :  5
#  6 - 8 years      :112   3rd Qu.:  12   SQL    :  5
#  9 - 12 years     : 70   Max.   :5759   matlab :  4
#  Less than 2 years:195   NA's   :543    (Other): 35
#   PG7Python       PG7Javascript  PG7Go     PG7C.        PG7Other
#        :1129             :1304     :1351     :1330          :1283
#  perl  :   1   Javascript:  48   Go:   2   C#:  23   Other  :  62
#  Python: 223   sql       :   1                       PHP    :   2
#                                                      Matlab :   1
#                                                      perl   :   1
#                                                      Ruby   :   1
#                                                      (Other):   3
#    PG7Submit                PG8Resp      PG8Submit           PG9Resp
#  Min.   :  1                    :570   Min.   :  1               :562
#  1st Qu.:  6   Data Scientist   :379   1st Qu.:  5   2 - 3       :229
#  Median :  8   Software Engineer: 55   Median :  8   4 - 6       :166
#  Mean   : 11   Student          : 24   Mean   : 12   7 - 10      :122
#  3rd Qu.: 11   Researcher       : 15   3rd Qu.: 14   1           : 94
#  Max.   :777   PhD student      : 10   Max.   :207   More than 25: 92
#  NA's   :542   (Other)          :300   NA's   :546   (Other)     : 88
#    PG9Submit                                            PG10Resp
#  Min.   :    0                                              :565
#  1st Qu.:    7   Native                                     :424
#  Median :   10   Not native - full working proficiency      :263
#  Mean   :   40   Not native - limited working proficiency   : 17
#  3rd Qu.:   14   Not native - passable                      :  5
#  Max.   :20126   Not native - sufficient working proficiency: 77
#  NA's   :547     Not native - very limited                  :  2
#    PG10Submit                   PG11Resp     PG11Submit         PG12Resp
#  Min.   :   1                       :576   Min.   :  1              :590
#  1st Qu.:   5   Female              : 96   1st Qu.:  4   18 - 24    : 34
#  Median :   7   Male                :652   Median :  4   25 - 34    :338
#  Mean   :  17   Prefer not to answer: 29   Mean   :  6   35 - 44    :258
#  3rd Qu.:  11                              3rd Qu.:  5   45 - 54    : 89
#  Max.   :5966                              Max.   :605   55 - 64    : 36
#  NA's   :546                               NA's   :548   65 and over:  8
#    PG12Submit
#  Min.   :   1
#  1st Qu.:   4
#  Median :   5
#  Mean   :   8
#  3rd Qu.:   6
#  Max.   :1566
#  NA's   :548

# %% [markdown]
# ## Interpret  and Clean Raw Data pt1
# Since we are dealing with the ranking of a question on PG5, we are going to want to ignore all other PG5 columns because they will heavily bias our model. We keep our response variable (PG5_2BNUI). This is the first step of cleaning our data.

# %%
# Get the column with our response variables (PG5_2BNUI)
cols = names(data)
print(cols)
pg5_2bnui = 25

# Get a list of columns to remove (all other PG5 variables)
pg5 = c(grep("PG5", col_names))
remove_indexes = pg5[-grep(pg5_2bnui, pg5)]

# Remove all other columns
data = data[,-remove_indexes]
summary(data)
# Out:
#  [1] "Device"        "Completed"     "Start"         "End"
#  [5] "PG0Dis"        "PG0Shown"      "PG0Submit"     "PG1PsnUse"
#  [9] "PG1WdAuth"     "PG1Trn"        "PG1Other"      "PG1Submit"
# [13] "PG2Resp"       "PG2Submit"     "PG2Resp.1"     "PG3Submit"
# [17] "PG4Dtr0_6"     "PG4Psv7_8"     "PG4Prm9_10"    "PG4AllResp"
# [21] "PG4Submit"     "PG5_1RRPQ"     "PG5_1Order"    "PG5_1Time"
# [25] "PG5_2BNUI"     "PG5_2Order"    "PG5_2Time"     "PG5_3HDS"
# [29] "PG5_3Order"    "PG5_3Time"     "PG5_4VGP"      "PG5_4Order"
# [33] "PG5_4Time"     "PG5_5PHR"      "PG5_5Order"    "PG5_5Time"
# [37] "PG5_6SSYOP"    "PG5_6Order"    "PG5_6Time"     "PG5_7NDYP"
# [41] "PG5_7Order"    "PG5_7Time"     "PG5_8CP"       "PG5_8Order"
# [45] "PG5_8Time"     "PG5_9FRP"      "PG5_9Order"    "PG5_9Time"
# [49] "PG5_10RPA"     "PG5_10Order"   "PG5_10Time"    "PG5_11NSG"
# [53] "PG5_11Order"   "PG5_11Time"    "PG5_12NWG"     "PG5_12Order"
# [57] "PG5_12Time"    "PG5_13NFG"     "PG5_13Order"   "PG5_13Time"
# [61] "PG5Submit"     "PG6Resp"       "PG6Submit"     "PG7R"
# [65] "PG7C.C.."      "PG7Java"       "PG7Python"     "PG7Javascript"
# [69] "PG7Go"         "PG7C."         "PG7Other"      "PG7Submit"
# [73] "PG8Resp"       "PG8Submit"     "PG9Resp"       "PG9Submit"
# [77] "PG10Resp"      "PG10Submit"    "PG11Resp"      "PG11Submit"
# [81] "PG12Resp"      "PG12Submit"
#      Device    Completed       Start               End               PG0Dis
#         :  2   0    :  2   Min.   :1.54e+09   Min.   :1.54e+09   Min.   :  0
#  Bot    :  1   FALSE:546   1st Qu.:1.54e+09   1st Qu.:1.54e+09   1st Qu.:  0
#  PC     :955   TRUE :805   Median :1.54e+09   Median :1.54e+09   Median :  1
#  Phone  :376               Mean   :1.54e+09   Mean   :1.54e+09   Mean   : 44
#  Tablet : 16               3rd Qu.:1.54e+09   3rd Qu.:1.54e+09   3rd Qu.: 24
#  Unknown:  3               Max.   :1.54e+09   Max.   :1.54e+09   Max.   :168
#                            NA's   :2          NA's   :548        NA's   :73
#     PG0Shown      PG0Submit                                     PG1PsnUse
#  Min.   :   0   Min.   :    2   For personal work and/or research use:727
#  1st Qu.:   0   1st Qu.:    6                                        :613
#  Median : 102   Median :    9   Chapter book                         :  1
#  Mean   : 249   Mean   :  299   dissertation research                :  1
#  3rd Qu.: 428   3rd Qu.:   15   for teaching                         :  1
#  Max.   :1190   Max.   :76226   for teaching undergraduate statistics:  1
#  NA's   :73     NA's   :199     (Other)                              :  9
#                                                                         PG1WdAuth
#                                                                              :1145
#  Because Microsoft was paying me to do it                                    :   1
#  For a wider audience, such as developers of other packages or other software: 205
#  Hackathon                                                                   :   1
#  Tool for other researchers to analyse their data                            :   1
#
#
#                                 PG1Trn
#                                    :1168
#  For a training / class that I took: 184
#  teaching economics                :   1
#
#
#
#
#                                                                PG1Other
#                                                                    :1272
#  Other                                                             :  23
#  teaching                                                          :   3
#  Teaching                                                          :   3
#  For training that I gave                                          :   2
#  How does software technology spreads in the open source community?:   2
#  (Other)                                                           :  48
#    PG1Submit        PG2Resp      PG2Submit
#  Min.   :   1           :431   Min.   :   1
#  1st Qu.:  11   No      :374   1st Qu.:   9
#  Median :  16   Not sure:303   Median :  13
#  Mean   :  39   Yes     :245   Mean   :  29
#  3rd Qu.:  30                  3rd Qu.:  29
#  Max.   :6892                  Max.   :1470
#  NA's   :282                   NA's   :377
#                                                                             PG2Resp.1
#                                                                                  :480
#  The core "data.frame" object lacked functionality that I needed                 :354
#  I saw a recommendation for the package                                          :149
#  Chose the package to be compatible with other packages in my project            :137
#  I didn't choose to use the package, it was included implicitly / unintentionally: 39
#  Other                                                                           :  6
#  (Other)                                                                         :188
#    PG3Submit      PG4Dtr0_6      PG4Psv7_8      PG4Prm9_10    PG4AllResp
#  Min.   :   1   Min.   :0      Min.   :7      Min.   : 9    Min.   : 0
#  1st Qu.:  16   1st Qu.:3      1st Qu.:7      1st Qu.:10    1st Qu.: 8
#  Median :  23   Median :5      Median :8      Median :10    Median : 9
#  Mean   :  44   Mean   :4      Mean   :8      Mean   :10    Mean   : 8
#  3rd Qu.:  40   3rd Qu.:6      3rd Qu.:8      3rd Qu.:10    3rd Qu.:10
#  Max.   :4648   Max.   :6      Max.   :8      Max.   :10    Max.   :10
#  NA's   :451    NA's   :1232   NA's   :1115   NA's   :869   NA's   :510
#    PG4Submit             PG5_2BNUI                PG6Resp      PG6Submit
#  Min.   :  1                  :923                    :549   Min.   :   1
#  1st Qu.:  6   Essential      :  3   13 - 19 years    : 50   1st Qu.:   7
#  Median :  7   High Priority  : 26   2 - 5 years      :332   Median :   9
#  Mean   :  9   Low Priority   :121   20 years or more : 45   Mean   :  24
#  3rd Qu.:  9   Medium Priority: 92   6 - 8 years      :112   3rd Qu.:  12
#  Max.   :332   Not a Priority :188   9 - 12 years     : 70   Max.   :5759
#  NA's   :473                         Less than 2 years:195   NA's   :543
#       PG7R      PG7C.C..     PG7Java      PG7Python       PG7Javascript
#  R      :684        :1268        :1306         :1129             :1304
#         :614   C/C++:  84   Java :  46   perl  :   1   Javascript:  48
#  Perl   :  6   Cobol:   1   scala:   1   Python: 223   sql       :   1
#  PHP    :  5
#  SQL    :  5
#  matlab :  4
#  (Other): 35
#  PG7Go     PG7C.        PG7Other      PG7Submit                PG8Resp
#    :1351     :1330          :1283   Min.   :  1                    :570
#  Go:   2   C#:  23   Other  :  62   1st Qu.:  6   Data Scientist   :379
#                      PHP    :   2   Median :  8   Software Engineer: 55
#                      Matlab :   1   Mean   : 11   Student          : 24
#                      perl   :   1   3rd Qu.: 11   Researcher       : 15
#                      Ruby   :   1   Max.   :777   PhD student      : 10
#                      (Other):   3   NA's   :542   (Other)          :300
#    PG8Submit           PG9Resp      PG9Submit
#  Min.   :  1               :562   Min.   :    0
#  1st Qu.:  5   2 - 3       :229   1st Qu.:    7
#  Median :  8   4 - 6       :166   Median :   10
#  Mean   : 12   7 - 10      :122   Mean   :   40
#  3rd Qu.: 14   1           : 94   3rd Qu.:   14
#  Max.   :207   More than 25: 92   Max.   :20126
#  NA's   :546   (Other)     : 88   NA's   :547
#                                         PG10Resp     PG10Submit
#                                             :565   Min.   :   1
#  Native                                     :424   1st Qu.:   5
#  Not native - full working proficiency      :263   Median :   7
#  Not native - limited working proficiency   : 17   Mean   :  17
#  Not native - passable                      :  5   3rd Qu.:  11
#  Not native - sufficient working proficiency: 77   Max.   :5966
#  Not native - very limited                  :  2   NA's   :546
#                  PG11Resp     PG11Submit         PG12Resp     PG12Submit
#                      :576   Min.   :  1              :590   Min.   :   1
#  Female              : 96   1st Qu.:  4   18 - 24    : 34   1st Qu.:   4
#  Male                :652   Median :  4   25 - 34    :338   Median :   5
#  Prefer not to answer: 29   Mean   :  6   35 - 44    :258   Mean   :   8
#                             3rd Qu.:  5   45 - 54    : 89   3rd Qu.:   6
#                             Max.   :605   55 - 64    : 36   Max.   :1566
#                             NA's   :548   65 and over:  8   NA's   :548

# %% [markdown]
# ## Interpret  and Clean Raw Data pt2
# We begin by looking at all the numeric fields remaining in our data set. We use these fields to look at their correlation. However, as you will notice, our response variable and the predictors we want to use are not shown here because they are not numeric fields. Let's work on the data some more in order to get better insight.

# %%
#get numeric fields only for correlation
sel = c()
for (i in 1:dim(data)[2]) if (is.numeric(data[,i])) sel = c(sel, i);


cor(data[,sel],method="spearman",use="pairwise.complete.obs"); #OK for any: uses ranks
# Out:
#            Start   End     PG0Dis  PG0Shown PG0Submit PG1Submit PG2Submit
# Start       1.0000  0.9952 -0.0417 -0.11507  0.135     0.1156    0.0791
# End         0.9952  1.0000 -0.0415 -0.09879  0.114     0.1550    0.0791
# PG0Dis     -0.0417 -0.0415  1.0000  0.87220  0.015     0.0065    0.0041
# PG0Shown   -0.1151 -0.0988  0.8722  1.00000  0.036     0.0205    0.0023
# PG0Submit   0.1350  0.1142  0.0153  0.03596  1.000     0.1088    0.1037
# PG1Submit   0.1156  0.1550  0.0065  0.02047  0.109     1.0000    0.1452
# PG2Submit   0.0791  0.0791  0.0041  0.00235  0.104     0.1452    1.0000
# PG3Submit   0.0384  0.0511  0.0567  0.04968  0.127     0.2688    0.2045
# PG4Dtr0_6   0.0121 -0.0518  0.1637  0.08226 -0.008    -0.0685    0.0015
# PG4Psv7_8   0.0037 -0.0458  0.0267  0.00036 -0.038     0.0566    0.0090
# PG4Prm9_10 -0.0267 -0.0267 -0.0092  0.03279 -0.094     0.0120   -0.0587
# PG4AllResp  0.0063 -0.0158  0.0018 -0.02094 -0.024     0.0297    0.0293
# PG4Submit   0.0187  0.0172 -0.0539 -0.05978  0.219     0.1651    0.1515
# PG6Submit   0.0054  0.0051  0.0277  0.04005  0.152     0.2414    0.2696
# PG7Submit   0.0776  0.0759  0.0097  0.01212  0.137     0.1133    0.1245
# PG8Submit   0.0441  0.0435  0.0354  0.02635  0.126     0.1069    0.1567
# PG9Submit   0.0410  0.0407  0.0099  0.00056  0.176     0.1090    0.2013
# PG10Submit  0.0474  0.0517 -0.0293 -0.04481  0.225     0.1701    0.0989
# PG11Submit  0.0790  0.0792 -0.0454 -0.07102  0.109     0.0738    0.1147
# PG12Submit  0.0746  0.0772  0.0546  0.04364  0.110     0.1137    0.1073
#            PG3Submit PG4Dtr0_6 PG4Psv7_8 PG4Prm9_10 PG4AllResp PG4Submit
# Start       0.0384    0.01210   0.00371  -2.7e-02    0.0063     0.019
# End         0.0511   -0.05185  -0.04576  -2.7e-02   -0.0158     0.017
# PG0Dis      0.0567    0.16368   0.02668  -9.2e-03    0.0018    -0.054
# PG0Shown    0.0497    0.08226   0.00036   3.3e-02   -0.0209    -0.060
# PG0Submit   0.1273   -0.00802  -0.03763  -9.4e-02   -0.0236     0.219
# PG1Submit   0.2688   -0.06852   0.05661   1.2e-02    0.0297     0.165
# PG2Submit   0.2045    0.00146   0.00897  -5.9e-02    0.0293     0.152
# PG3Submit   1.0000    0.00865   0.04424  -6.2e-03   -0.0193     0.196
# PG4Dtr0_6   0.0087    1.00000        NA        NA    1.0000    -0.143
# PG4Psv7_8   0.0442         NA   1.00000        NA    1.0000    -0.083
# PG4Prm9_10 -0.0062         NA        NA   1.0e+00    1.0000    -0.194
# PG4AllResp -0.0193    1.00000   1.00000   1.0e+00    1.0000    -0.269
# PG4Submit   0.1956   -0.14272  -0.08350  -1.9e-01   -0.2687     1.000
# PG6Submit   0.2706   -0.16179  -0.01463  -4.2e-02   -0.0040     0.333
# PG7Submit   0.1316    0.15596  -0.03631  -6.3e-02   -0.0753     0.278
# PG8Submit   0.1822    0.06953   0.05260  -5.5e-02   -0.1294     0.182
# PG9Submit   0.2745   -0.07292   0.05977  -3.0e-02   -0.0381     0.332
# PG10Submit  0.1614    0.04433   0.06942  -6.1e-02   -0.1060     0.391
# PG11Submit  0.1383    0.00084  -0.04870  -8.6e-05   -0.0820     0.276
# PG12Submit  0.1642   -0.02721  -0.02169   1.7e-02   -0.0668     0.236
#            PG6Submit PG7Submit PG8Submit PG9Submit PG10Submit PG11Submit
# Start       0.0054    0.0776    0.044     0.04101   0.047      7.9e-02
# End         0.0051    0.0759    0.044     0.04071   0.052      7.9e-02
# PG0Dis      0.0277    0.0097    0.035     0.00995  -0.029     -4.5e-02
# PG0Shown    0.0401    0.0121    0.026     0.00056  -0.045     -7.1e-02
# PG0Submit   0.1518    0.1365    0.126     0.17579   0.225      1.1e-01
# PG1Submit   0.2414    0.1133    0.107     0.10895   0.170      7.4e-02
# PG2Submit   0.2696    0.1245    0.157     0.20127   0.099      1.1e-01
# PG3Submit   0.2706    0.1316    0.182     0.27450   0.161      1.4e-01
# PG4Dtr0_6  -0.1618    0.1560    0.070    -0.07292   0.044      8.4e-04
# PG4Psv7_8  -0.0146   -0.0363    0.053     0.05977   0.069     -4.9e-02
# PG4Prm9_10 -0.0418   -0.0633   -0.055    -0.02989  -0.061     -8.6e-05
# PG4AllResp -0.0040   -0.0753   -0.129    -0.03812  -0.106     -8.2e-02
# PG4Submit   0.3326    0.2775    0.182     0.33236   0.391      2.8e-01
# PG6Submit   1.0000    0.3086    0.207     0.44528   0.343      2.8e-01
# PG7Submit   0.3086    1.0000    0.161     0.27819   0.312      2.8e-01
# PG8Submit   0.2065    0.1606    1.000     0.25569   0.200      2.1e-01
# PG9Submit   0.4453    0.2782    0.256     1.00000   0.290      2.8e-01
# PG10Submit  0.3428    0.3121    0.200     0.29018   1.000      3.5e-01
# PG11Submit  0.2777    0.2768    0.207     0.27906   0.346      1.0e+00
# PG12Submit  0.2904    0.2523    0.193     0.27550   0.313      2.5e-01
#            PG12Submit
# Start       0.075
# End         0.077
# PG0Dis      0.055
# PG0Shown    0.044
# PG0Submit   0.110
# PG1Submit   0.114
# PG2Submit   0.107
# PG3Submit   0.164
# PG4Dtr0_6  -0.027
# PG4Psv7_8  -0.022
# PG4Prm9_10  0.017
# PG4AllResp -0.067
# PG4Submit   0.236
# PG6Submit   0.290
# PG7Submit   0.252
# PG8Submit   0.193
# PG9Submit   0.275
# PG10Submit  0.313
# PG11Submit  0.251
# PG12Submit  1.000

# %% [markdown]
# ## Interpret  and Clean Raw Data pt3
# Since some of our fields are non-numeric, lets transform our dataset to contain all numeric fields. This is possible using the is.factor() to classify our ranges/rankings as numbers for most of the survey responses. Using this transformed data set, lets look at the highly correlated ( > 0.7 ) fields using the function described in Dr. Mockus' lecture.

# %%
# Transform our non-numeric data into numeric
for (i in 1:dim(data)[2]) if (is.factor(data[,i])) data[,i] = as.numeric(data[,i]);
for(i in 1:ncol(data)){
  data[is.na(data[,i]), i] <- mean(data[,i], na.rm = TRUE)
}

# %%
# Define a function - same as fdacState.ipynb lecture
hiCor <- function(x, level){
  res <- cor(x,method="spearman", use='pairwise.complete.obs');
  res1 <- res; res1[res<0] <- -res[res < 0];
  for (i in 1:dim(x)[2]){
    res1[i,i] <- 0;
  }
  sel <- apply(res1,1,max) > level;
  res[sel,sel];
}
hiCor(data,.7)
# Out:
#            Completed PG0Dis   PG0Shown PG2Resp.1 PG6Resp PG6Submit PG7R
# Completed   1.000    -0.01554  1.2e-02  0.730     0.875  -0.78      0.8714
# PG0Dis     -0.016     1.00000  8.5e-01  0.025     0.011   0.02     -0.0084
# PG0Shown    0.012     0.85391  1.0e+00  0.041     0.020   0.01      0.0138
# PG2Resp.1   0.730     0.02535  4.1e-02  1.000     0.650  -0.56      0.6511
# PG6Resp     0.875     0.01114  2.0e-02  0.650     1.000  -0.71      0.7755
# PG6Submit  -0.777     0.02013  1.0e-02 -0.564    -0.708   1.00     -0.6908
# PG7R        0.871    -0.00842  1.4e-02  0.651     0.775  -0.69      1.0000
# PG8Resp     0.860    -0.01494  5.9e-03  0.635     0.775  -0.67      0.7457
# PG9Resp     0.860    -0.00695  2.1e-02  0.657     0.733  -0.67      0.7632
# PG9Submit  -0.824    -0.00026 -2.6e-02 -0.600    -0.719   0.77     -0.7476
# PG10Resp    0.878     0.00279  1.3e-02  0.656     0.784  -0.63      0.7657
# PG10Submit -0.760    -0.00753 -3.2e-02 -0.558    -0.640   0.71     -0.6867
# PG11Resp    0.908    -0.01959  8.2e-03  0.679     0.789  -0.70      0.8036
# PG12Resp    0.852    -0.01476  6.0e-06  0.640     0.742  -0.62      0.7453
#            PG8Resp PG9Resp PG9Submit PG10Resp PG10Submit PG11Resp PG12Resp
# Completed   0.8598  0.860  -0.82428   0.8783  -0.7599     0.9081   8.5e-01
# PG0Dis     -0.0149 -0.007  -0.00026   0.0028  -0.0075    -0.0196  -1.5e-02
# PG0Shown    0.0059  0.021  -0.02597   0.0128  -0.0319     0.0082   6.0e-06
# PG2Resp.1   0.6349  0.657  -0.60038   0.6560  -0.5578     0.6794   6.4e-01
# PG6Resp     0.7746  0.733  -0.71933   0.7836  -0.6400     0.7888   7.4e-01
# PG6Submit  -0.6688 -0.670   0.76868  -0.6331   0.7137    -0.6992  -6.2e-01
# PG7R        0.7457  0.763  -0.74757   0.7657  -0.6867     0.8036   7.5e-01
# PG8Resp     1.0000  0.742  -0.70798   0.7733  -0.6259     0.8050   7.4e-01
# PG9Resp     0.7417  1.000  -0.71107   0.7419  -0.6789     0.8093   7.7e-01
# PG9Submit  -0.7080 -0.711   1.00000  -0.6864   0.7278    -0.7546  -7.1e-01
# PG10Resp    0.7733  0.742  -0.68640   1.0000  -0.4664     0.8124   7.3e-01
# PG10Submit -0.6259 -0.679   0.72781  -0.4664   1.0000    -0.6746  -6.5e-01
# PG11Resp    0.8050  0.809  -0.75464   0.8124  -0.6746     1.0000   8.0e-01
# PG12Resp    0.7367  0.770  -0.70902   0.7322  -0.6469     0.7970   1.0e+00

# %% [markdown]
# ## Correlation Analysis
# To get a better look at the correlation between all of the remaining predictors/survey questions, lets look at all of their adjusted R^2 values. I use the same method described in the fdacStats.ipynb example.

# %%
#regress each predictor on the remaining predictors
# eliminate with the highest adjR^2
res <- c();
vnam <- names(data);
for (i in 2:dim(data)[2]){
  fmla <- as.formula(paste(vnam[i],paste(vnam[-c(1,i)],collapse="+"),sep="~"));
  res <- rbind(res,c(i,round(summary(lm(fmla,data=data))$r.squared,2)));
}
row.names(res) <- vnam[res[,1]];
res[order(-res[,2]),];
# Out:
#               [,1] [,2]
# Completed      2   0.93
# PG11Resp      40   0.85
# PG7R          25   0.80
# PG12Resp      42   0.70
# PG9Resp       36   0.69
# PG6Resp       23   0.63
# Start          3   0.57
# End            4   0.56
# PG8Resp       34   0.54
# PG10Resp      38   0.50
# PG0Shown       6   0.46
# PG2Resp       13   0.46
# PG0Dis         5   0.44
# PG2Resp.1     15   0.42
# PG8Submit     35   0.34
# PG5_2BNUI     22   0.29
# PG1PsnUse      8   0.28
# PG9Submit     37   0.28
# PG1Trn        10   0.23
# PG4AllResp    20   0.23
# PG7Python     28   0.21
# PG4Dtr0_6     17   0.19
# PG7Other      32   0.17
# PG7C.C..      26   0.14
# PG7C.         31   0.12
# PG7Java       27   0.11
# PG1WdAuth      9   0.10
# PG7Submit     33   0.10
# PG7Javascript 29   0.09
# PG2Submit     14   0.08
# PG10Submit    39   0.08
# PG4Submit     21   0.07
# PG4Psv7_8     18   0.06
# PG4Prm9_10    19   0.06
# PG1Other      11   0.05
# PG3Submit     16   0.04
# PG1Submit     12   0.03
# PG6Submit     24   0.03
# PG7Go         30   0.03
# PG0Submit      7   0.02
# PG11Submit    41   0.02
# PG12Submit    43   0.02

# %% [markdown]
# ## Correlation Analysis cont.
# We drop all of the columns with an adjR^2 value >= 0.85. This results in dropping Completed and PG11Resp. Now that we have our desired predictors (all of the remaining columns), lets fit our model. Note, this measure might not be the best because it has a lot of noise since we are using every other column in the survey to model our response variable. However, we can use this as inisght into fitting our model.

# %%
data = data[, -which(names(data) %in% c("Completed", "PG11Resp"))]
summary(data)
# Out:
#      Device        Start               End               PG0Dis
#  Min.   :1.0   Min.   :1.54e+09   Min.   :1.54e+09   Min.   :  0
#  1st Qu.:3.0   1st Qu.:1.54e+09   1st Qu.:1.54e+09   1st Qu.:  0
#  Median :3.0   Median :1.54e+09   Median :1.54e+09   Median :  1
#  Mean   :3.3   Mean   :1.54e+09   Mean   :1.54e+09   Mean   : 44
#  3rd Qu.:4.0   3rd Qu.:1.54e+09   3rd Qu.:1.54e+09   3rd Qu.: 44
#  Max.   :6.0   Max.   :1.54e+09   Max.   :1.54e+09   Max.   :168
#     PG0Shown      PG0Submit       PG1PsnUse      PG1WdAuth       PG1Trn
#  Min.   :   0   Min.   :    2   Min.   : 1.0   Min.   :1.0   Min.   :1.00
#  1st Qu.:   0   1st Qu.:    6   1st Qu.: 1.0   1st Qu.:1.0   1st Qu.:1.00
#  Median : 130   Median :   10   Median : 4.0   Median :1.0   Median :1.00
#  Mean   : 249   Mean   :  299   Mean   : 2.7   Mean   :1.3   Mean   :1.14
#  3rd Qu.: 399   3rd Qu.:   28   3rd Qu.: 4.0   3rd Qu.:1.0   3rd Qu.:1.00
#  Max.   :1190   Max.   :76226   Max.   :15.0   Max.   :5.0   Max.   :3.00
#     PG1Other    PG1Submit       PG2Resp      PG2Submit      PG2Resp.1
#  Min.   : 1   Min.   :   1   Min.   :1.0   Min.   :   1   Min.   :  1
#  1st Qu.: 1   1st Qu.:  12   1st Qu.:1.0   1st Qu.:  10   1st Qu.:  1
#  Median : 1   Median :  21   Median :2.0   Median :  20   Median : 46
#  Mean   : 3   Mean   :  39   Mean   :2.3   Mean   :  29   Mean   : 62
#  3rd Qu.: 1   3rd Qu.:  39   3rd Qu.:3.0   3rd Qu.:  29   3rd Qu.:148
#  Max.   :53   Max.   :6892   Max.   :4.0   Max.   :1470   Max.   :184
#    PG3Submit      PG4Dtr0_6     PG4Psv7_8     PG4Prm9_10     PG4AllResp
#  Min.   :   1   Min.   :0.0   Min.   :7.0   Min.   : 9.0   Min.   : 0.0
#  1st Qu.:  19   1st Qu.:4.2   1st Qu.:7.6   1st Qu.: 9.8   1st Qu.: 8.0
#  Median :  40   Median :4.2   Median :7.6   Median : 9.8   Median : 8.4
#  Mean   :  44   Mean   :4.2   Mean   :7.6   Mean   : 9.8   Mean   : 8.4
#  3rd Qu.:  44   3rd Qu.:4.2   3rd Qu.:7.6   3rd Qu.:10.0   3rd Qu.:10.0
#  Max.   :4648   Max.   :6.0   Max.   :8.0   Max.   :10.0   Max.   :10.0
#    PG4Submit     PG5_2BNUI      PG6Resp      PG6Submit         PG7R
#  Min.   :  1   Min.   :1.0   Min.   :1.0   Min.   :   1   Min.   : 1
#  1st Qu.:  6   1st Qu.:1.0   1st Qu.:1.0   1st Qu.:   8   1st Qu.: 1
#  Median :  9   Median :1.0   Median :3.0   Median :  15   Median :22
#  Mean   :  9   Mean   :2.3   Mean   :3.1   Mean   :  24   Mean   :12
#  3rd Qu.:  9   3rd Qu.:4.0   3rd Qu.:5.0   3rd Qu.:  24   3rd Qu.:22
#  Max.   :332   Max.   :6.0   Max.   :7.0   Max.   :5759   Max.   :33
#     PG7C.C..       PG7Java       PG7Python    PG7Javascript      PG7Go
#  Min.   :1.00   Min.   :1.00   Min.   :1.00   Min.   :1.00   Min.   :1
#  1st Qu.:1.00   1st Qu.:1.00   1st Qu.:1.00   1st Qu.:1.00   1st Qu.:1
#  Median :1.00   Median :1.00   Median :1.00   Median :1.00   Median :1
#  Mean   :1.06   Mean   :1.04   Mean   :1.33   Mean   :1.04   Mean   :1
#  3rd Qu.:1.00   3rd Qu.:1.00   3rd Qu.:1.00   3rd Qu.:1.00   3rd Qu.:1
#  Max.   :3.00   Max.   :3.00   Max.   :3.00   Max.   :3.00   Max.   :2
#      PG7C.         PG7Other     PG7Submit      PG8Resp      PG8Submit
#  Min.   :1.00   Min.   :1.0   Min.   :  1   Min.   :  1   Min.   :  1
#  1st Qu.:1.00   1st Qu.:1.0   1st Qu.:  7   1st Qu.:  1   1st Qu.:  7
#  Median :1.00   Median :1.0   Median : 11   Median : 50   Median : 12
#  Mean   :1.02   Mean   :1.1   Mean   : 11   Mean   : 51   Mean   : 12
#  3rd Qu.:1.00   3rd Qu.:1.0   3rd Qu.: 11   3rd Qu.: 50   3rd Qu.: 12
#  Max.   :2.00   Max.   :9.0   Max.   :777   Max.   :204   Max.   :207
#     PG9Resp      PG9Submit        PG10Resp   PG10Submit     PG11Submit
#  Min.   :1.0   Min.   :    0   Min.   :1   Min.   :   1   Min.   :  1
#  1st Qu.:1.0   1st Qu.:    9   1st Qu.:1   1st Qu.:   7   1st Qu.:  4
#  Median :3.0   Median :   16   Median :2   Median :  13   Median :  6
#  Mean   :3.5   Mean   :   40   Mean   :2   Mean   :  17   Mean   :  6
#  3rd Qu.:6.0   3rd Qu.:   40   3rd Qu.:3   3rd Qu.:  17   3rd Qu.:  6
#  Max.   :8.0   Max.   :20126   Max.   :7   Max.   :5966   Max.   :605
#     PG12Resp     PG12Submit
#  Min.   :1.0   Min.   :   1
#  1st Qu.:1.0   1st Qu.:   5
#  Median :3.0   Median :   7
#  Mean   :2.5   Mean   :   8
#  3rd Qu.:4.0   3rd Qu.:   8
#  Max.   :7.0   Max.   :1566

# %% [markdown]
# ## Fitting the Model and Coefficient Analysis
# Since I have little experience with machine learning and models, I followed the fdacStats lecture when doing my modeling and used a **generalized linear model**. For this first run, I simply used every remaining column in the dataset as a predictor. The results showed that a majority of the coefficients did not have a signficant impact on my response variable. Because this measure is quite noisy, I tried to fit the model better a second time.

# %%
mod <- glm(PG5_2BNUI ~ .,data=data);
summary(mod);
# Out:
# Call:
# glm(formula = PG5_2BNUI ~ ., data = data)
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -3.232  -1.508  -0.112   0.916   4.984
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.74e+02   3.46e+02    0.50  0.61535
# Device        -1.04e-01   9.32e-02   -1.11  0.26601
# Start         -8.27e-08   2.45e-07   -0.34  0.73616
# End           -2.85e-08   3.28e-07   -0.09  0.93067
# PG0Dis        -3.21e-04   9.34e-04   -0.34  0.73139
# PG0Shown       1.26e-04   2.07e-04    0.61  0.54421
# PG0Submit     -1.22e-05   1.32e-05   -0.92  0.35557
# PG1PsnUse     -1.80e-02   3.26e-02   -0.55  0.58099
# PG1WdAuth      1.14e-01   6.67e-02    1.71  0.08775 .
# PG1Trn        -8.58e-02   1.51e-01   -0.57  0.57039
# PG1Other       1.69e-03   6.27e-03    0.27  0.78748
# PG1Submit     -3.10e-04   2.04e-04   -1.52  0.12929
# PG2Resp        7.15e-02   5.69e-02    1.26  0.20872
# PG2Submit      6.69e-04   7.64e-04    0.88  0.38161
# PG2Resp.1      5.09e-05   9.37e-04    0.05  0.95671
# PG3Submit      4.48e-04   3.33e-04    1.35  0.17864
# PG4Dtr0_6     -8.92e-02   9.07e-02   -0.98  0.32538
# PG4Psv7_8     -2.49e-01   2.36e-01   -1.05  0.29255
# PG4Prm9_10    -8.04e-02   1.93e-01   -0.42  0.67713
# PG4AllResp     5.94e-02   3.13e-02    1.90  0.05743 .
# PG4Submit     -5.03e-03   3.62e-03   -1.39  0.16460
# PG6Resp        1.19e-01   3.28e-02    3.64  0.00029 ***
# PG6Submit     -3.84e-04   2.29e-04   -1.68  0.09382 .
# PG7R           3.60e-02   8.40e-03    4.29  1.9e-05 ***
# PG7C.C..      -3.49e-01   2.00e-01   -1.74  0.08211 .
# PG7Java       -2.37e-01   2.59e-01   -0.92  0.35989
# PG7Python      1.04e-01   6.98e-02    1.49  0.13765
# PG7Javascript  6.23e-03   2.51e-01    0.02  0.98020
# PG7Go          1.43e+00   1.22e+00    1.18  0.23800
# PG7C.         -1.46e-01   3.79e-01   -0.39  0.69999
# PG7Other       8.17e-02   8.72e-02    0.94  0.34878
# PG7Submit      3.03e-03   2.24e-03    1.35  0.17706
# PG8Resp        3.30e-03   1.09e-03    3.04  0.00240 **
# PG8Submit     -2.04e-03   5.26e-03   -0.39  0.69881
# PG9Resp        5.37e-02   3.07e-02    1.75  0.08027 .
# PG9Submit      1.67e-04   9.89e-05    1.69  0.09092 .
# PG10Resp       1.51e-02   4.76e-02    0.32  0.75128
# PG10Submit    -3.32e-04   2.93e-04   -1.13  0.25719
# PG11Submit     2.42e-04   2.55e-03    0.10  0.92419
# PG12Resp       5.77e-02   5.10e-02    1.13  0.25796
# PG12Submit    -1.69e-03   1.09e-03   -1.55  0.12130
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 2.9)
#
#     Null deviance: 5166.2  on 1352  degrees of freedom
# Residual deviance: 3764.3  on 1312  degrees of freedom
# AIC: 5308
#
# Number of Fisher Scoring iterations: 2

# %% [markdown]
# ## Modeling and Coefficient Analysis cont.
# Using our first model above, with all columns as predictors, I took all the resulting coefficients with a p value < 1 and used those as the predictors for this model. The model is still a generalized linear model, just with specific predictors this time. We get a lower AIC score with our second model, so it is the one I ended up using for final results.

# %%
mod2 <- glm(PG5_2BNUI ~ PG1WdAuth+PG4AllResp+PG6Resp+PG6Submit+PG7R+PG8Resp+PG9Resp+PG9Submit,data=data)
summary(mod2);
# Out:
# Call:
# glm(formula = PG5_2BNUI ~ PG1WdAuth + PG4AllResp + PG6Resp +
#     PG6Submit + PG7R + PG8Resp + PG9Resp + PG9Submit, data = data)
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -2.985  -1.548  -0.136   0.850   4.924
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  3.94e-01   2.56e-01    1.54  0.12357
# PG1WdAuth    1.23e-01   6.43e-02    1.91  0.05615 .
# PG4AllResp   4.44e-02   2.77e-02    1.60  0.10966
# PG6Resp      1.33e-01   3.06e-02    4.35  1.5e-05 ***
# PG6Submit   -3.81e-04   2.26e-04   -1.68  0.09229 .
# PG7R         4.20e-02   7.43e-03    5.65  2.0e-08 ***
# PG8Resp      3.32e-03   9.92e-04    3.34  0.00085 ***
# PG9Resp      7.25e-02   2.73e-02    2.65  0.00810 **
# PG9Submit    1.53e-04   8.41e-05    1.82  0.06889 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for gaussian family taken to be 2.9)
#
#     Null deviance: 5166.2  on 1352  degrees of freedom
# Residual deviance: 3855.2  on 1344  degrees of freedom
# AIC: 5276
#
# Number of Fisher Scoring iterations: 2

# %% [markdown]
# ## Results
# The results of our second model above show that my hypothesis is not supported because the PG9Resp question was not the most significant when predicting my response variable. In fact, PG6Resp was one of the most signficant predictors (development experience), along with PG7R and PG8Resp. To me, these other predictors make a lot of sense and do not seem arbitrary (i.e. The more development experience someone has, the more likely they have been exposed to a variety of packages and libraries. This is a similar premise I had with my hypothesis and PG9Resp (number of projects involved with)). However, I did only use a linear model, which might not be the best for a categorical survey like this, and could have seen different results using another model like Random Forest.
