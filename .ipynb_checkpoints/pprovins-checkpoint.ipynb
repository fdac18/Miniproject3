# %% [markdown]
# Hypothesis
# ======
#
# I am to model the data according to response "PG5_1RRPQ" - Resolve Reported Problem Quickly.
# The details about a respondants:
#
# * position at time of commit
# * level of developement experience
# * age
#
# Are prime candidates for predictors as the job position is indicitive of the work being done. Software Engineer may want maintainable code and elect a solution that is not immediate, but sustainable. Other position may want a quick solution that is discardable. Developer experience plays into effect as developers with lesser experience may opt for solutions that cut corners for immediate satisfaction. Gender was intended to be used but there were more male responses than female responses, so age was elected instead as a predictor as yoounger individuals would be expected to find a solution that requires less work on their end as they are typically "fire and forget" programmers.
#
# Modelling
# ======
# I plan on using a linear regression model using the predictors above.
#
# I will attribute to position at time of commit the following values:
#
# * Software Engineer - 3
# * Data Scientist - 2
# * Other - 1
#
# I will attribute to level of experience the following values:
#
# * <2 Years - 6
# * 2-5 Years - 5
# * 6-8 Years - 4
# * 9-12 Years - 3
# * 13-19 Years - 2
# * 20+ Years - 1
#
# I will attribute to age the following values:
#
# * 18-24 - 1
# * 25-34 - 2
# * 35-44 - 3
# * 45-54 - 4
# * 55-64 - 5
# * 65+   - 6

# %%
# For nicer printing
options(digits=2);

#libraries
library(dplyr);
library(tidyr);
library(ggplot2)

# %%
# Read in the data
data <- read.csv("TechSurvey - Survey.csv",header=T);

#remove other variables, not involved with the repsonse RRPQ
extra_vars <- c("PG5_2BNUI",
                "PG5_2Order",
                "PG5_2Time",
                "PG5_3HDS",
                "PG5_3Order",
                "PG5_3Time",
                "PG5_4VGP",
                "PG5_4Order",
                "PG5_4Time",
                "PG5_5PHR",
                "PG5_5Order",
                "PG5_5Time",
                "PG5_6SSYOP",
                "PG5_6Order",
                "PG5_6Time",
                "PG5_7NDYP",
                "PG5_7Order",
                "PG5_7Time",
                "PG5_8CP",
                "PG5_8Order",
                "PG5_8Time",
                "PG5_9FRP",
                "PG5_9Order",
                "PG5_9Time",
                "PG5_10RPA",
                "PG5_10Order",
                "PG5_10Time",
                "PG5_11NSG",
                "PG5_11Order",
                "PG5_11Time",
                "PG5_12NWG",
                "PG5_12Order",
                "PG5_12Time",
                "PG5_13NFG",
                "PG5_13Order",
                "PG5_13Time")

#divide off data fields of extra_vars from data set
data <- data %>% select(-c(extra_vars))

#convert date to unix second
for (i in c("Start", "End")) 
    data[,i] = as.numeric(as.POSIXct(strptime(data[,i], "%Y-%m-%d %H:%M:%S")))
for (i in 0:12){
    vnam = paste(c("PG",i,"Submit"), collapse="")
    data[,vnam] = as.numeric(as.POSIXct(strptime(data[,vnam], "%Y-%m-%d %H:%M:%S")))
}
#calculate differences in time    
for (i in 12:0){
    pv = paste(c("PG",i-1,"Submit"), collapse="");
    if (i==0) 
        pv="Start";
    vnam = paste(c("PG",i,"Submit"), collapse="");
    data[,vnam] = data[,vnam] -data[,pv];
}

#remove not completed
data_completed = filter(data, Completed == TRUE)

# %%
#now explore variables
summary(data);
# Out:
#      Device    Completed       Start               End               PG0Dis
#         :  2   0    :  2   Min.   :1.54e+09   Min.   :1.54e+09   Min.   :  0
#  Bot    :  1   FALSE:546   1st Qu.:1.54e+09   1st Qu.:1.54e+09   1st Qu.:  0
#  PC     :955   TRUE :805   Median :1.54e+09   Median :1.54e+09   Median :  1
#  Phone  :376               Mean   :1.54e+09   Mean   :1.54e+09   Mean   : 44
#  Tablet : 16               3rd Qu.:1.54e+09   3rd Qu.:1.54e+09   3rd Qu.: 24
#  Unknown:  3               Max.   :1.54e+09   Max.   :1.54e+09   Max.   :168
#                            NA's   :2          NA's   :548        NA's   :73
#     PG0Shown      PG0Submit
#  Min.   :   0   Min.   :    2
#  1st Qu.:   0   1st Qu.:    6
#  Median : 102   Median :    9
#  Mean   : 249   Mean   :  299
#  3rd Qu.: 428   3rd Qu.:   15
#  Max.   :1190   Max.   :76226
#  NA's   :73     NA's   :199
#                                        PG1PsnUse
#  For personal work and/or research use      :727
#                                             :613
#  Chapter book                               :  1
#  For training attendees of my sessions      :  1
#  It's a coures on tidyverse that I developed:  1
#  Learning how to create a package           :  1
#  (Other)                                    :  9
#                                                                         PG1WdAuth
#                                                                              :1145
#  Because Microsoft was paying me to do it                                    :   1
#  For a wider audience, such as developers of other packages or other software: 205
#  Hackathon                                                                   :   1
#  Tool for other researchers to analyse their data                            :   1
#
#
#                                 PG1Trn
#                                    :1168
#  For a training / class that I took: 184
#  teaching economics                :   1
#
#
#
#
#                                                                PG1Other
#                                                                    :1272
#  Other                                                             :  23
#  Teaching                                                          :   3
#  teaching                                                          :   3
#  For training that I gave                                          :   2
#  How does software technology spreads in the open source community?:   2
#  (Other)                                                           :  48
#    PG1Submit        PG2Resp      PG2Submit
#  Min.   :   1           :431   Min.   :   1
#  1st Qu.:  11   No      :374   1st Qu.:   9
#  Median :  16   Not sure:303   Median :  13
#  Mean   :  39   Yes     :245   Mean   :  29
#  3rd Qu.:  30                  3rd Qu.:  29
#  Max.   :6892                  Max.   :1470
#  NA's   :282                   NA's   :377
#                                                                             PG2Resp.1
#                                                                                  :480
#  The core "data.frame" object lacked functionality that I needed                 :354
#  I saw a recommendation for the package                                          :149
#  Chose the package to be compatible with other packages in my project            :137
#  I didn't choose to use the package, it was included implicitly / unintentionally: 39
#  Other                                                                           :  6
#  (Other)                                                                         :188
#    PG3Submit      PG4Dtr0_6      PG4Psv7_8      PG4Prm9_10    PG4AllResp
#  Min.   :   1   Min.   :0      Min.   :7      Min.   : 9    Min.   : 0
#  1st Qu.:  16   1st Qu.:3      1st Qu.:7      1st Qu.:10    1st Qu.: 8
#  Median :  23   Median :5      Median :8      Median :10    Median : 9
#  Mean   :  44   Mean   :4      Mean   :8      Mean   :10    Mean   : 8
#  3rd Qu.:  40   3rd Qu.:6      3rd Qu.:8      3rd Qu.:10    3rd Qu.:10
#  Max.   :4648   Max.   :6      Max.   :8      Max.   :10    Max.   :10
#  NA's   :451    NA's   :1232   NA's   :1115   NA's   :869   NA's   :510
#    PG4Submit             PG5_1RRPQ     PG5_1Order                PG5_1Time
#  Min.   :  1                  :877   Min.   : 1                       :877
#  1st Qu.:  6   Essential      : 60   1st Qu.: 4    2018-10-11 13:32:57:  3
#  Median :  7   High Priority  :102   Median : 7    2018-10-11 13:29:20:  2
#  Mean   :  9   Low Priority   : 85   Mean   : 7    2018-10-11 13:34:56:  2
#  3rd Qu.:  9   Medium Priority:134   3rd Qu.:11    2018-10-11 13:14:25:  1
#  Max.   :332   Not a Priority : 95   Max.   :20    2018-10-11 13:14:45:  1
#  NA's   :473                         NA's   :877   (Other)            :467
#    PG5Submit                 PG6Resp      PG6Submit         PG7R
#  Min.   :   3                    :549   Min.   :   1   R      :684
#  1st Qu.:  45   13 - 19 years    : 50   1st Qu.:   7          :614
#  Median :  62   2 - 5 years      :332   Median :   9   Perl   :  6
#  Mean   :  87   20 years or more : 45   Mean   :  24   PHP    :  5
#  3rd Qu.:  84   6 - 8 years      :112   3rd Qu.:  12   SQL    :  5
#  Max.   :4130   9 - 12 years     : 70   Max.   :5759   Ruby   :  4
#  NA's   :544    Less than 2 years:195   NA's   :543    (Other): 35
#   PG7C.C..     PG7Java      PG7Python       PG7Javascript  PG7Go     PG7C.
#       :1268        :1306         :1129             :1304     :1351     :1330
#  C/C++:  84   Java :  46   Python: 223   Javascript:  48   Go:   2   C#:  23
#  Cobol:   1   scala:   1   perl  :   1   sql       :   1
#
#
#
#
#     PG7Other      PG7Submit                PG8Resp      PG8Submit
#         :1283   Min.   :  1                    :570   Min.   :  1
#  Other  :  62   1st Qu.:  6   Data Scientist   :379   1st Qu.:  5
#  PHP    :   2   Median :  8   Software Engineer: 55   Median :  8
#  Matlab :   1   Mean   : 11   Student          : 24   Mean   : 12
#  Ruby   :   1   3rd Qu.: 11   Researcher       : 15   3rd Qu.: 14
#  SAS    :   1   Max.   :777   PhD student      : 10   Max.   :207
#  (Other):   3   NA's   :542   (Other)          :300   NA's   :546
#          PG9Resp      PG9Submit
#              :562   Min.   :    0
#  2 - 3       :229   1st Qu.:    7
#  4 - 6       :166   Median :   10
#  7 - 10      :122   Mean   :   40
#  1           : 94   3rd Qu.:   14
#  More than 25: 92   Max.   :20126
#  (Other)     : 88   NA's   :547
#                                         PG10Resp     PG10Submit
#                                             :565   Min.   :   1
#  Native                                     :424   1st Qu.:   5
#  Not native - full working proficiency      :263   Median :   7
#  Not native - limited working proficiency   : 17   Mean   :  17
#  Not native - passable                      :  5   3rd Qu.:  11
#  Not native - sufficient working proficiency: 77   Max.   :5966
#  Not native - very limited                  :  2   NA's   :546
#                  PG11Resp     PG11Submit         PG12Resp     PG12Submit
#                      :576   Min.   :  1              :590   Min.   :   1
#  Female              : 96   1st Qu.:  4   18 - 24    : 34   1st Qu.:   4
#  Male                :652   Median :  4   25 - 34    :338   Median :   5
#  Prefer not to answer: 29   Mean   :  6   35 - 44    :258   Mean   :   8
#                             3rd Qu.:  5   45 - 54    : 89   3rd Qu.:   6
#                             Max.   :605   55 - 64    : 36   Max.   :1566
#                             NA's   :548   65 and over:  8   NA's   :548

# %% [markdown]
# ### Interpret  basic summaries

# %%
#get numeric fields only for correlation
sel = c()
for (i in 1:dim(data)[2]) if (is.numeric(data[,i])) sel = c(sel, i);


cor(data[,sel],method="spearman",use="pairwise.complete.obs"); #OK for any: uses ranks
# Out:
#            Start   End     PG0Dis  PG0Shown PG0Submit PG1Submit PG2Submit
# Start       1.0000  0.9952 -0.0417 -0.11507  0.135     0.1156    0.0791
# End         0.9952  1.0000 -0.0415 -0.09879  0.114     0.1550    0.0791
# PG0Dis     -0.0417 -0.0415  1.0000  0.87220  0.015     0.0065    0.0041
# PG0Shown   -0.1151 -0.0988  0.8722  1.00000  0.036     0.0205    0.0023
# PG0Submit   0.1350  0.1142  0.0153  0.03596  1.000     0.1088    0.1037
# PG1Submit   0.1156  0.1550  0.0065  0.02047  0.109     1.0000    0.1452
# PG2Submit   0.0791  0.0791  0.0041  0.00235  0.104     0.1452    1.0000
# PG3Submit   0.0384  0.0511  0.0567  0.04968  0.127     0.2688    0.2045
# PG4Dtr0_6   0.0121 -0.0518  0.1637  0.08226 -0.008    -0.0685    0.0015
# PG4Psv7_8   0.0037 -0.0458  0.0267  0.00036 -0.038     0.0566    0.0090
# PG4Prm9_10 -0.0267 -0.0267 -0.0092  0.03279 -0.094     0.0120   -0.0587
# PG4AllResp  0.0063 -0.0158  0.0018 -0.02094 -0.024     0.0297    0.0293
# PG4Submit   0.0187  0.0172 -0.0539 -0.05978  0.219     0.1651    0.1515
# PG5_1Order  0.0218  0.0196  0.0140  0.01254 -0.024     0.0750   -0.0069
# PG5Submit   0.0851  0.0909  0.0060 -0.00888  0.177     0.2467    0.2185
# PG6Submit   0.0054  0.0051  0.0277  0.04005  0.152     0.2414    0.2696
# PG7Submit   0.0776  0.0759  0.0097  0.01212  0.137     0.1133    0.1245
# PG8Submit   0.0441  0.0435  0.0354  0.02635  0.126     0.1069    0.1567
# PG9Submit   0.0410  0.0407  0.0099  0.00056  0.176     0.1090    0.2013
# PG10Submit  0.0474  0.0517 -0.0293 -0.04481  0.225     0.1701    0.0989
# PG11Submit  0.0790  0.0792 -0.0454 -0.07102  0.109     0.0738    0.1147
# PG12Submit  0.0746  0.0772  0.0546  0.04364  0.110     0.1137    0.1073
#            PG3Submit PG4Dtr0_6 PG4Psv7_8 ... PG4Submit PG5_1Order PG5Submit
# Start       0.0384    0.01210   0.00371  ...  0.019     0.0218     0.08512
# End         0.0511   -0.05185  -0.04576  ...  0.017     0.0196     0.09088
# PG0Dis      0.0567    0.16368   0.02668  ... -0.054     0.0140     0.00601
# PG0Shown    0.0497    0.08226   0.00036  ... -0.060     0.0125    -0.00888
# PG0Submit   0.1273   -0.00802  -0.03763  ...  0.219    -0.0240     0.17671
# PG1Submit   0.2688   -0.06852   0.05661  ...  0.165     0.0750     0.24670
# PG2Submit   0.2045    0.00146   0.00897  ...  0.152    -0.0069     0.21851
# PG3Submit   1.0000    0.00865   0.04424  ...  0.196     0.0578     0.26048
# PG4Dtr0_6   0.0087    1.00000        NA  ... -0.143    -0.0949    -0.05214
# PG4Psv7_8   0.0442         NA   1.00000  ... -0.083    -0.0140     0.08974
# PG4Prm9_10 -0.0062         NA        NA  ... -0.194    -0.0171     0.00077
# PG4AllResp -0.0193    1.00000   1.00000  ... -0.269     0.1189     0.01248
# PG4Submit   0.1956   -0.14272  -0.08350  ...  1.000    -0.0487     0.27328
# PG5_1Order  0.0578   -0.09488  -0.01399  ... -0.049     1.0000     0.08054
# PG5Submit   0.2605   -0.05214   0.08974  ...  0.273     0.0805     1.00000
# PG6Submit   0.2706   -0.16179  -0.01463  ...  0.333     0.0334     0.32240
# PG7Submit   0.1316    0.15596  -0.03631  ...  0.278     0.0173     0.23120
# PG8Submit   0.1822    0.06953   0.05260  ...  0.182    -0.0388     0.20351
# PG9Submit   0.2745   -0.07292   0.05977  ...  0.332     0.0103     0.30291
# PG10Submit  0.1614    0.04433   0.06942  ...  0.391    -0.0957     0.26881
# PG11Submit  0.1383    0.00084  -0.04870  ...  0.276    -0.0245     0.23552
# PG12Submit  0.1642   -0.02721  -0.02169  ...  0.236     0.0238     0.25876
#            PG6Submit PG7Submit PG8Submit PG9Submit PG10Submit PG11Submit
# Start       0.0054    0.0776    0.044     0.04101   0.047      7.9e-02
# End         0.0051    0.0759    0.044     0.04071   0.052      7.9e-02
# PG0Dis      0.0277    0.0097    0.035     0.00995  -0.029     -4.5e-02
# PG0Shown    0.0401    0.0121    0.026     0.00056  -0.045     -7.1e-02
# PG0Submit   0.1518    0.1365    0.126     0.17579   0.225      1.1e-01
# PG1Submit   0.2414    0.1133    0.107     0.10895   0.170      7.4e-02
# PG2Submit   0.2696    0.1245    0.157     0.20127   0.099      1.1e-01
# PG3Submit   0.2706    0.1316    0.182     0.27450   0.161      1.4e-01
# PG4Dtr0_6  -0.1618    0.1560    0.070    -0.07292   0.044      8.4e-04
# PG4Psv7_8  -0.0146   -0.0363    0.053     0.05977   0.069     -4.9e-02
# PG4Prm9_10 -0.0418   -0.0633   -0.055    -0.02989  -0.061     -8.6e-05
# PG4AllResp -0.0040   -0.0753   -0.129    -0.03812  -0.106     -8.2e-02
# PG4Submit   0.3326    0.2775    0.182     0.33236   0.391      2.8e-01
# PG5_1Order  0.0334    0.0173   -0.039     0.01033  -0.096     -2.5e-02
# PG5Submit   0.3224    0.2312    0.204     0.30291   0.269      2.4e-01
# PG6Submit   1.0000    0.3086    0.207     0.44528   0.343      2.8e-01
# PG7Submit   0.3086    1.0000    0.161     0.27819   0.312      2.8e-01
# PG8Submit   0.2065    0.1606    1.000     0.25569   0.200      2.1e-01
# PG9Submit   0.4453    0.2782    0.256     1.00000   0.290      2.8e-01
# PG10Submit  0.3428    0.3121    0.200     0.29018   1.000      3.5e-01
# PG11Submit  0.2777    0.2768    0.207     0.27906   0.346      1.0e+00
# PG12Submit  0.2904    0.2523    0.193     0.27550   0.313      2.5e-01
#            PG12Submit
# Start       0.075
# End         0.077
# PG0Dis      0.055
# PG0Shown    0.044
# PG0Submit   0.110
# PG1Submit   0.114
# PG2Submit   0.107
# PG3Submit   0.164
# PG4Dtr0_6  -0.027
# PG4Psv7_8  -0.022
# PG4Prm9_10  0.017
# PG4AllResp -0.067
# PG4Submit   0.236
# PG5_1Order  0.024
# PG5Submit   0.259
# PG6Submit   0.290
# PG7Submit   0.252
# PG8Submit   0.193
# PG9Submit   0.275
# PG10Submit  0.313
# PG11Submit  0.251
# PG12Submit  1.000

# %% [markdown]
# Interpret correlations: onlys start vs End, calculate differene instead

# %%
# Get rid of empty responses
new_data <- filter(data, PG5_1RRPQ != "")
new_data <- filter(data, PG6Resp != "")
new_data <- filter(data, PG8Resp != "")
new_data <- filter(data, PG12Resp != "")

# Convert PG6Resp to be usable by linear regression model
levels(data$PG6Resp) <- c(levels(data$PG6Resp), 0, 1, 2, 3, 4, 5, 6)
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == ""), '0')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "Less than 2 years"), '6')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "2 - 5 years"), '5')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "6 - 8 years"), '4')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "9 - 12 years"), '3')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "13 - 19 years"), '2')
new_data$PG6Resp <- replace(new_data$PG6Resp, which(new_data$PG6Resp == "20 years or more"), '1')
new_data <- transform(new_data, PG6Resp = as.numeric(as.character(PG6Resp)))

# Convert PG9Resp to be usable by linear regression model
levels(data$PG8Resp) <- c(levels(data$PG8Resp), 0, 1, 2, 3)
new_data$PG8Resp <- replace(new_data$PG8Resp, which(new_data$PG8Resp == ""), '0')
new_data$PG8Resp <- replace(new_data$PG8Resp, which(new_data$PG8Resp == "Other"), '1')
new_data$PG8Resp <- replace(new_data$PG8Resp, which(new_data$PG8Resp != "Software Engineer" &
                                                    new_data$PG8Resp != "Data Scientist"), '1')
new_data$PG8Resp <- replace(new_data$PG8Resp, which(new_data$PG8Resp == "Data Scientist"), '2')
new_data$PG8Resp <- replace(new_data$PG8Resp, which(new_data$PG8Resp == "Software Engineer"), '3')
new_data <- transform(new_data, PG8Resp = as.numeric(as.character(PG8Resp)))

# Convert PG12Resp to be usable by linear regression model
levels(data$PG12Resp) <- c(levels(data$PG12Resp), 0, 1, 2, 3, 4, 5, 6)
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == ""), '0')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "18 - 24"), '6')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "25 - 34"), '5')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "35 - 44"), '4')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "45 - 54"), '3')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "55 - 64"), '2')
new_data$PG12Resp <- replace(new_data$PG12Resp, which(new_data$PG12Resp == "65 and over"), '1')
new_data <- transform(new_data, PG12Resp = as.numeric(as.character(PG12Resp)))

#Convert PG5_1RRPQ to be usable by linear regression model
levels(data$PG5_1RRPQ) <- c(levels(data$PG5_1RRPQ), 0, 1, 2, 3, 4, 5)
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == ""), '0')
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == "Not a Priority"), '1')
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == "Low Priority"), '2')
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == "Medium Priority"), '3')
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == "High Priority"), '4')
new_data$PG5_1RRPQ <- replace(new_data$PG5_1RRPQ, which(new_data$PG5_1RRPQ == "Essential"), '5')
new_data <- transform(new_data, PG5_1RRPQ = as.numeric(as.character(PG5_1RRPQ)))

print(summary(new_data$PG6Resp))
print(summary(new_data$PG8Resp))
print(summary(new_data$PG12Resp))
print(summary(new_data$PG5_1RRPQ))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     4.0     5.0     4.5     5.0     6.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     1.0     2.0     1.6     2.0     3.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     4.0     4.0     4.3     5.0     6.0
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     0.0     0.0     1.0     1.7     3.0     5.0

# %%
# Define a function
hiCor <- function(data, level){
  results <- cor(data, method="spearman", use="pairwise.complete.obs");
  # set NA to 0
  results[is.na(results)] <- 0
  
  # convert negative correlations to positive
  pos_results <- results;
  pos_results[results < 0] <- -results[results < 0];
    
  # set diagonal to 0
  for (i in 1:dim(data)[2]){
    pos_results[i,i] <- 0;
  }
  
  sel <- apply(pos_results, 1, max) > level;
  results[sel,sel];
}
high_corr <- hiCor(new_data[, sel],.7)

# print high correlations
print(summary(high_corr))
# Out:
#      Start            End            PG0Dis         PG0Shown
#  Min.   :-0.09   Min.   :-0.11   Min.   :-0.05   Min.   :-0.09
#  1st Qu.:-0.05   1st Qu.:-0.06   1st Qu.:-0.02   1st Qu.:-0.04
#  Median :-0.03   Median :-0.03   Median : 0.02   Median : 0.01
#  Mean   : 0.21   Mean   : 0.21   Mean   : 0.26   Mean   : 0.24
#  3rd Qu.: 0.24   3rd Qu.: 0.24   3rd Qu.: 0.42   3rd Qu.: 0.40
#  Max.   : 1.00   Max.   : 1.00   Max.   : 1.00   Max.   : 1.00
#    PG4Dtr0_6       PG4Psv7_8       PG4Prm9_10      PG4AllResp
#  Min.   :-0.11   Min.   :-0.05   Min.   :-0.01   Min.   :-0.02
#  1st Qu.:-0.02   1st Qu.:-0.03   1st Qu.:-0.01   1st Qu.:-0.01
#  Median : 0.12   Median : 0.00   Median : 0.00   Median : 0.50
#  Mean   : 0.29   Mean   : 0.24   Mean   : 0.25   Mean   : 0.49
#  3rd Qu.: 0.46   3rd Qu.: 0.27   3rd Qu.: 0.28   3rd Qu.: 1.00
#  Max.   : 1.00   Max.   : 1.00   Max.   : 1.00   Max.   : 1.00

# %%
model_pg6 <- lm(PG5_1RRPQ ~ PG6Resp, data = new_data)
summary(model_pg6)

ggplot(new_data, aes(x = PG6Resp, y = PG5_1RRPQ)) + 
  geom_point() +
  stat_smooth(method = "lm", col = "red") +
  labs(title = paste("Adj R2 = ",signif(summary(model_pg6)$adj.r.squared, 5),
                     "Intercept =",signif(model_pg6$coef[[1]], 5),
                     " Slope =",signif(model_pg6$coef[[2]], 5),
                     " P =",signif(summary(model_pg6)$coef[2,4], 5)))
# Out:
# Call:
# lm(formula = PG5_1RRPQ ~ PG6Resp, data = new_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.758 -1.697 -0.635  1.303  3.550
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.3885     0.2060    6.74  3.1e-11 ***
# PG6Resp       0.0616     0.0436    1.41     0.16
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.7 on 761 degrees of freedom
# Multiple R-squared:  0.00262,	Adjusted R-squared:  0.00131
# F-statistic:    2 on 1 and 761 DF,  p-value: 0.158
# plot without title

# %%
model_pg8 <- lm(PG5_1RRPQ ~ PG8Resp, data = new_data)
summary(model_pg8)

ggplot(new_data, aes(x = PG8Resp, y = PG5_1RRPQ)) + 
  geom_point() +
  stat_smooth(method = "lm", col = "blue") +
  labs(title = paste("Adj R2 = ",signif(summary(model_pg8)$adj.r.squared, 5),
                     "Intercept =",signif(model_pg8$coef[[1]], 5),
                     " Slope =",signif(model_pg8$coef[[2]], 5),
                     " P =",signif(summary(model_pg8)$coef[2,4], 5)))
# Out:
# Call:
# lm(formula = PG5_1RRPQ ~ PG8Resp, data = new_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.722 -1.628 -0.628  1.372  3.465
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.8151     0.1763   10.30   <2e-16 ***
# PG8Resp      -0.0934     0.1031   -0.91     0.37
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.7 on 761 degrees of freedom
# Multiple R-squared:  0.00108,	Adjusted R-squared:  -0.000235
# F-statistic: 0.821 on 1 and 761 DF,  p-value: 0.365
# plot without title

# %%
model_pg12 <- lm(PG5_1RRPQ ~ PG12Resp, data = new_data)
summary(model_pg12)

ggplot(new_data, aes(x = PG12Resp, y = PG5_1RRPQ)) + 
  geom_point() +
  stat_smooth(method = "lm", col = "green") +
  labs(title = paste("Adj R2 = ",signif(summary(model_pg12)$adj.r.squared, 5),
                     "Intercept =",signif(model_pg12$coef[[1]], 5),
                     " Slope =",signif(model_pg12$coef[[2]], 5),
                     " P =",signif(summary(model_pg12)$coef[2,4], 5)))
# Out:
# Call:
# lm(formula = PG5_1RRPQ ~ PG12Resp, data = new_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.775 -1.647 -0.647  1.353  3.481
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.3907     0.2842    4.89  1.2e-06 ***
# PG12Resp      0.0641     0.0646    0.99     0.32
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.7 on 761 degrees of freedom
# Multiple R-squared:  0.00129,	Adjusted R-squared:  -1.98e-05
# F-statistic: 0.985 on 1 and 761 DF,  p-value: 0.321
# plot without title

# %%
model_all <- lm(PG5_1RRPQ ~ PG6Resp + PG8Resp + PG12Resp, data = new_data)
summary(model_all)

ggplot(new_data, aes(x = PG6Resp + PG8Resp + PG12Resp, y = PG5_1RRPQ)) + 
  geom_point() +
  stat_smooth(method = "lm", col = "red") +
  labs(title = paste("Adj R2 = ",signif(summary(model_all)$adj.r.squared, 5),
                     "Intercept =",signif(model_all$coef[[1]], 5),
                     " Slope =",signif(model_all$coef[[2]] + model_all$coef[[3]] + model_all$coef[[4]], 5),
                     " P =",signif(summary(model_all)$coef[2,4], 5)))
# Out:
# Call:
# lm(formula = PG5_1RRPQ ~ PG6Resp + PG8Resp + PG12Resp, data = new_data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -1.834 -1.654 -0.639  1.346  3.671
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.4132     0.3738    3.78  0.00017 ***
# PG6Resp       0.0487     0.0473    1.03  0.30429
# PG8Resp      -0.0660     0.1050   -0.63  0.53004
# PG12Resp      0.0324     0.0696    0.47  0.64126
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.7 on 759 degrees of freedom
# Multiple R-squared:  0.00348,	Adjusted R-squared:  -0.000457
# F-statistic: 0.884 on 3 and 759 DF,  p-value: 0.449
# plot without title

# %% [markdown]
# ### Simple questions
#
# - Time to take entire survey?
# - Question that took the longest to complete?
# - Question that took the least time?
# - Top-ranked criteria?
# - Demographic distribution by age?
